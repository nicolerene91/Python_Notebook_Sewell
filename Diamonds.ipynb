# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolerene91/diamonds/blob/main/Diamonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import .csv file from github. create and display numeric/categorical data from
# diamonds.csv file w/histogram
# Nicole Sewell, 23T1 Troy University
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# data from github
url = 'https://raw.githubusercontent.com/nicolerene91/diamonds/main/diamonds.csv'
df = pd.read_csv(url)

print(df.head(7))
print("\n", df.tail(7))

# describe and show the numerical statistics for diamonds
numeric_stats = df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].describe()
print("\nNumerical stats:\n", numeric_stats)
# describe and show the categorical statistics for diamonds
categorical_stats = df[['cut', 'color', 'clarity']].describe()
print("\nCategorical stats:\n", categorical_stats)
# unique values for cut, color, and clarity
unique_cut_values = ", " .join(df['cut'].unique())
unique_color_values = ", " .join(df['color'].unique())
unique_clarity_values = ", " .join(df['clarity'].unique())
print("\nUnique cut values:", unique_cut_values)
print("Unique color values:", unique_color_values)
print("Unique clarity values:", unique_clarity_values)
# create histogram for numerical data columns
df.hist(figsize=(8, 6))
# display the histogram
plt.tight_layout()
plt.show()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
#
#         Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# ...
